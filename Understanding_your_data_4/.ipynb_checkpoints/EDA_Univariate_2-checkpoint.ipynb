# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df['Survived'].unique())
# Out:
# [0 1]

# %%
df['Survived'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# # <h3> Count plot </h3>

# %%
# Using matplotlib directly
#import seaborn as sns

#plt.figure(figsize=(8, 6))
df['Survived'].value_counts().plot(kind='bar')
# plt.xlabel('Survived')
# plt.ylabel('Number of Passenger')
# plt.title('Count of Survived')
# plt.show()
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Sex'].value_counts().plot(kind = 'bar')
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# # <h3> Pie chart </h3>

# %%
df['Pclass'].value_counts().plot(kind = 'pie', autopct = '%.2f')
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind = 'pie', autopct = '%.2f')
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# # <h3>a. Histogram </h3>

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins= 10)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # <h3>a. Distplot </h3>

# %%
sns.distplot(x=df['Age'])
# Out:
# C:\Users\Hare Krishna\AppData\Local\Temp\ipykernel_75228\2735538418.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['Age'])        # It is not working well, actually it will show probability of perticular value
# C:\python3.7\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %% [markdown]
# # <h3>a. Boxplot </h3>

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
# Other functions

df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Fare'].skew()                   # If it is positive it mean that Fare is more if is is negative
#it mean that Fare is less and if it is exact Zero it mean that Fare is normal
# Out:
# 4.787316519674893
