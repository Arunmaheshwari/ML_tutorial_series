# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://www.glassdoor.co.in/Explore/browse-companies.htm?overall_rating_low=3.5&page=1', headers = headers).text

# %%
webpage
# Out:
# '<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<title>Security | Glassdoor</title>\n\t\t<meta http-equiv="content-type" content="text/html;charset=utf-8" />\n\t\t<meta name=\'viewport\' content=\'width=device-width, initial-scale=1\'/>\n\t\t<meta name="theme-color" content="#0caa41">\n\t\t<style type="text/css">body,html{background:#fff;font-family:Helvetica Neue,HelveticaNeue,Helvetica,Arial,sans-serif;font-size:16px;margin:0;padding:0}div,h1,h2,h3,h4,h5,h6,p{color:#20262e}.header{-webkit-box-shadow:inset 0 -1px 0 0 #dee0e3;box-shadow:inset 0 -1px 0 0 #dee0e3}.header .center{height:45px}.header .center:before{content:"";height:100%;margin-right:-.25em}.header .center:before,.logo{display:inline-block;vertical-align:middle}.center{margin:0 auto;width:996px}.article,.center{box-sizing:border-box}.article{background-color:#fff;border-radius:3px;box-shadow:0 0 2px #c4c7cc;height:100%;margin:16px 0;max-width:690px;padding:16px}h1{font-size:20px;font-weight:900;line-height:1em;margin-top:0}h2{font-size:18px;font-weight:400;margin:16px 0}@media only screen and (max-width:767px){.header .center{text-align:center}.center{padding:0;width:100%}.article{margin:16px;max-width:none}}@media only screen and (min-width:768px) and (max-width:1023px){.center{margin:0;padding:0 14px;width:100%}}</style>\n\t<meta http-equiv="refresh" content="375">\n</head>\n\t<body>\n\t\t<div class=\'header\'>\n\t\t\t<div class=\'center\'>\n\t\t\t\t<img class=\'logo\' src="data:image/png;base64,..." width=\'144\' height=\'30\' />\n\t\t\t</div>\n\t\t</div>\n\t\t<div class=\'center\'>\n<div class=\'article lang en-us\'>\n\t<h1>Help Us Protect Glassdoor</h1>\n\t<p>\n\t\tPlease help us protect Glassdoor by verifying that you\'re a\n\t\treal person. We are sorry for the inconvenience. If you continue to see this \n\t\tmessage, please email\n\t\t<img src="data:image/jpeg;base64,..." style=\'margin-bottom:-4px\' />\n\t\tto let us know you\'re having trouble.\n\t</p>\n</div>\n<div class=\'article lang fr-fr\'>\n\t<h1>Aidez-nous à protéger Glassdoor</h1>\n\t<p>\n\t\tAidez-nous à protéger Glassdoor en confirmant que vous êtes une personne réelle.\n\t\tNous sommes désolés pour la gêne occasionnée. Si vous continuez à voir ce\n\t\tmessage, contactez-nous à l\'adresse\n\t\t<img src="data:image/jpeg;base64,..." style=\'margin-bottom:-4px\' />\n\t\tpour nous faire part du problème. \n\t</p>\n</div>\n<div class=\'article lang de-de\'>\n\t<h1>Helfen Sie mit, Glassdoor zu schützen</h1>\n\t<p>\n\t\tBitte helfen Sie uns, Glassdoor zu schützen, indem Sie bestätigen, dass Sie\n\t\tein Mensch und keine Maschine sind. Wir entschuldigen uns für die Umstände. Wenn\n\t\tSie weiterhin diese Meldung erhalten, informieren Sie uns darüber bitte per E-Mail\n\t\tan\n\t\t<img src="data:image/jpeg;base64,..." style=\'margin-bottom:-4px\' /> \n\t</p>\n</div>\n<div class=\'article lang nl-nl\'>\n\t<h1>Help ons Glassdoor te beschermen</h1>\n\t<p>\n\t\tHelp ons Glassdoor te beschermen door te verifiëren of u een persoon bent. Onze\n\t\texcuses voor het ongemak. Als u dit bericht blijft zien, stuur dan een e-mail\n\t\tnaar\n\t\t<img src="data:image/jpeg;base64,..." style=\'margin-bottom:-4px\' />\n\t\tom ons te informeren over dit probleem.\n\t</p>\n</div>\n<div class=\'article lang es-es\'>\n\t<h1>Ayúdanos a proteger Glassdoor</h1>\n\t<p>\n\t\tAyúdanos a proteger Glassdoor y demuéstranos que eres una persona real. Disculpa\n\t\tlas molestias. Si continúas recibiendo este mensaje, infórmanos del problema\n\t\tenviando un correo electrónico a\n\t\t<img src="data:image/jpeg;base64,..." style=\'margin-bottom:-4px\' />.\n\t</p>\n</div>\n<div class=\'article lang es-419\'>\n\t<h1>Ayúdanos a proteger Glassdoor</h1>\n\t<p>\n\t\tAyúdanos a proteger Glassdoor verificando que eres una persona real. Lamentamos\n\t\tlos inconvenientes que esto te pueda causar. Si continúas viendo este mensaje,\n\t\tenvía un correo electrónico a\n\t\t<img src="data:image/jpeg;base64,..." style=\'margin-bottom:-4px\' />\n\t\tpara informar ...

# %%
soup = BeautifulSoup(webpage, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Security | Glassdoor</title>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="#0caa41" name="theme-color"/>
# <style type="text/css">body,html{background:#fff;font-family:Helvetica Neue,HelveticaNeue,Helvetica,Arial,sans-serif;font-size:16px;margin:0;padding:0}div,h1,h2,h3,h4,h5,h6,p{color:#20262e}.header{-webkit-box-shadow:inset 0 -1px 0 0 #dee0e3;box-shadow:inset 0 -1px 0 0 #dee0e3}.header .center{height:45px}.header .center:before{content:"";height:100%;margin-right:-.25em}.header .center:before,.logo{display:inline-block;vertical-align:middle}.center{margin:0 auto;width:996px}.article,.center{box-sizing:border-box}.article{background-color:#fff;border-radius:3px;box-shadow:0 0 2px #c4c7cc;height:100%;margin:16px 0;max-width:690px;padding:16px}h1{font-size:20px;font-weight:900;line-height:1em;margin-top:0}h2{font-size:18px;font-weight:400;margin:16px 0}@media only screen and (max-width:767px){.header .center{text-align:center}.center{padding:0;width:100%}.article{margin:16px;max-width:none}}@media only screen and (min-width:768px) and (max-width:1023px){.center{margin:0;padding:0 14px;width:100%}}</style>
# <meta content="375" http-equiv="refresh"/>
# </head>
# <body>
# <div class="header">
# <div class="center">
# <img class="logo" height="30" src="data:image/png;base64,..." width="144"/>
# </div>
# </div>
# <div class="center">
# <div class="article lang en-us">
# <h1>Help Us Protect Glassdoor</h1>
# <p>
# 		Please help us protect Glassdoor by verifying that you're a
# 		real person. We are sorry for the inconvenience. If you continue to see this
# 		message, please email
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
# 		to let us know you're having trouble.
# 	</p>
# </div>
# <div class="article lang fr-fr">
# <h1>Aidez-nous à protéger Glassdoor</h1>
# <p>
# 		Aidez-nous à protéger Glassdoor en confirmant que vous êtes une personne réelle.
# 		Nous sommes désolés pour la gêne occasionnée. Si vous continuez à voir ce
# 		message, contactez-nous à l'adresse
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
# 		pour nous faire part du problème.
# 	</p>
# </div>
# <div class="article lang de-de">
# <h1>Helfen Sie mit, Glassdoor zu schützen</h1>
# <p>
# 		Bitte helfen Sie uns, Glassdoor zu schützen, indem Sie bestätigen, dass Sie
# 		ein Mensch und keine Maschine sind. Wir entschuldigen uns für die Umstände. Wenn
# 		Sie weiterhin diese Meldung erhalten, informieren Sie uns darüber bitte per E-Mail
# 		an
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
# </p>
# </div>
# <div class="article lang nl-nl">
# <h1>Help ons Glassdoor te beschermen</h1>
# <p>
# 		Help ons Glassdoor te beschermen door te verifiëren of u een persoon bent. Onze
# 		excuses voor het ongemak. Als u dit bericht blijft zien, stuur dan een e-mail
# 		naar
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
# 		om ons te informeren over dit probleem.
# 	</p>
# </div>
# <div class="article lang es-es">
# <h1>Ayúdanos a proteger Glassdoor</h1>
# <p>
# 		Ayúdanos a proteger Glassdoor y demuéstranos que eres una persona real. Disculpa
# 		las molestias. Si continúas recibiendo este mensaje, infórmanos del problema
# 		enviando un correo electrónico a
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>.
# 	</p>
# </div>
# <div class="article lang es-419">
# <h1>Ayúdanos a proteger Glassdoor</h1>
# <p>
# 		Ayúdanos a proteger Glassdoor verificando que eres una persona real. Lamentamos
# 		los inconvenientes que esto te pueda causar. Si continúas viendo este mensaje,
# 		envía un correo electrónico a
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
# 		para informarnos de que tienes problemas.
# 	</p>
# </div>
# <div class="article lang pt-br">
# <h1>Ajude-nos a proteger o Glassdoor</h1>
# <p>
# 		Ajude-nos a manter o Glassdoor seguro confirmando que você é uma pessoa de
# 		verdade. Lamentamos pelo inconveniente. Caso continue recebendo esta mensagem,
# 		envie um e-mail para
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
# 		para nos informar sobre o problema.
# 	</p>
# </div>
# <div class="article lang it-it">
# <h1>Aiutaci a proteggere Glassdoor</h1>
# <p>
# 		Aiutaci a proteggere Glassdoor dimostrando che sei una persona reale. Ci
# 		scusiamo se questo può causarti degli inconvenienti. Se continui a visualizzare
# 		questo messaggio, invia un'email all'indirizzo
# 		<img src="data:image/jpeg;base64,..." style="margin-bottom:-4px"/>
# 		per informarci del problema.
# 	</p>
# </div>
# <div class="article">
# <p>
# 		CF-103 / 85e933d15cd78af3
# 	</p>
# <p>
# <form class="challenge-form" id="challenge-form"><div id="cf-please-wait"><div id="spinner"><div id="cf-bubbles"><div class="bubbles"></div><div class="bubbles"></div><div class="bubbles"></div></div></div><p id="cf-spinner-please-wait"></p><p id="cf-spinner-redirecting" style="display:none"></p></div><noscript class="cf-captcha-info" id="cf-captcha-bookmark"><h1 style="color:#bd2426;">Please turn JavaScript on and reload the page.</h1></noscript><div class="cookie-warning" id="no-cookie-warning" style="display:none"><p style="color:#bd2426;">Please enable Cookies and reload the page.</p></div></form><script>(function(){window._cf_chl_opt={cvId: '3',cZone: "www.glassdoor.co.in",cType: 'managed',cNounce: '64783',cRay: '85e933d15cd78af3',cHash: 'cbc220d391bae17',cUPMDTk: "\/Explore\/browse-companies.htm?overall_rating_low=3.5&page=1&__cf_chl_tk=CxLBRtcOfZ0BlgqU75EXxd8gqskvcbKsuifZ9fUF1MQ-1709464461-0.0.1.1-1727",cFPWv: 'g',cTTimeMs: '1000',cMTimeMs: '375000',cTplV: 1,cTplB: 'cf',cK: "visitor-time",fa: "\/Explore\/browse-companies.htm?overall_rating_low=3.5&page=1&__cf_chl_f_tk=CxLBRtcOfZ0BlgqU75EXxd8gqskvcbKsuifZ9fUF1MQ-1709464461-0.0.1.1-1727",md: "w.1fpQ6O8AYonnMeFQyQB4._xtjvLS.XXLw6pgho8cs-1709464461-1.1.1.1-DRzKuiw8nqprLeJQgd1a2h6Vj2.rhXyyStZz_d1jrQsoDItfdcay.K3fCeT9.eAQM0CwpTEZ1KoYmrA9mKnD8Xo_gLKmY0mScz3uM79eCUOwt1u.I8SywEdfiO..4sdIjaBgmwDAflnRBKN5ktPFcI5iAqOyU7njo5GpMzIWMyZO1k.R1hve7xoLoAfXjxxhcdfLJae415dcrWx.Jx7Wh8yOnLQDwdX7SAKcMfrlMYbrKriwhHEkzQU7BfB2_dsAub2FgiarKhq85fJUtp.x5vZ4SrAMZbIvJUTDcotN7j_o5SSdPqGbFM_xNU7608V89tk3Qe6RKAsvM3uReXyoIQ8i1hKC7L4vF5cUpM8U2mPWfMBA5znrYw2KGeQtVtwbIbmwtWNhIZwUwtBpHXvV98kiBZbVngZVUwNVk5gqxbGpZ31gJr2Cwvd1gp3jJqpWHanW1yf.re4qEnygQxkPkVpX73mEsceuxLmjgNRMSq2jUC04Fvv5g9KjxShxJ_rqCPflfy6Hw7Ayhz06eiaMXt.OJwRhTZ7XYdsOweXxmWmeo0SqiG62bQmEpRpOPqxlsaE3NvW11DcsMQaoxq19ye0TnH9oL5_JrjZCENoHcspIjx6hvyHTcZeLrGUx_cMEd_j8fQKRMY6JldC1KHA6Ow0AsQwsnR7ciiVjHVTMMbcjw0ySXHqSQxwph.7vzuwsWgTMrW0MMIz1nnSyKrzz8jaCo68sPAB0pTNxdR9JmVNXN81k0krhkcModdOByQkutXHFwpUkLQ_tx1gtwtx.mJ5YMoTMfzK1PTGsNLWt4Xq5ZtLhQty4uXxfcoEPhyeIEmiOTN.M5L463_z8Ao9lbI47_qnPLCa.dvQdA9SFDW_6TCgbwsyzZzNzRbj18IwuzFrRt3ACK6mzuyfY1HNF96HfltEHQ8e7vcNbmyHKhDrU5fhMVCj4lk69XuyvC0wQeomVzekrUTpoO_Lki_y2UCODjnwliD7Kkb3yaXv9rMmOTSpK0BsZfnvYrN1kc6EeHeA5RUkT_myYalsxvs6Rs5WF6fsBcw2InTEHJFdAaP_NC.JilqOgneRPxS9XlVYtTEbaFtvUrbjruqfURV6r5dPbQdF4n1WMo3hiKR3DkKxXLV3m1bkma6d9r571JkZmTK.O1J3zmYpYVUpVlp0.DzlXrf3WNJEa_IgXCEMrLgEYVX6rWsiMAP9TEW_.jvVcqE8HQlCc1XueUhci6aGaxBvMELWhb8LTdKrjt.3.DarAfz6kBwwSLQiaIR5_6Ubo6OG6lua2VLkGAusgvs8FoTfJrUzNmkKhPZvZuQ6tDbkBOdyiKpJciO_b.W8cxIEWPYuh7RKOmYWdF7kWBAvuVdZKbeMclr7DKttfpTZvD_yr0dWyE1DsVf9zn8KhSmDO2nn12868yWUU1lsLuuX9AkiDK04T_yJD3XvbDlqFZAqDDvDUu8lwZZJO4.H6R1dqmhicJcnfxDmFEZu2B42h0tDbWAImZ1RK3gPWBR0X.GueelgTyLQ_ZSALPZlve_atdeX5SfVfSbIjI7LTQWFEdBAglZ_ODr1CEvvQJugWt5yO9IU58kA5tYELllw8lsT.LxqBjlCV7aT7ZRuE5dpGxDs3PYbmIkgjs4LkKfrSpEZsQKfyDfecVOuO7DkAmplg",mdrd: "kf1SHiJIhL.RGQSJE0FaWTLaZrUwGOp2lOlV8HAgoSQ-1709464461-1.1.1.1-cw.ZYO7WxcDQ4NkDifsWe80ilOCyDu3.2FwCvfd8qI3ZkO0pqoHfHzUOXbTr.tDDGwGKyuUmRzwXrAzzKF8ZNIfZczvBZcLKYVP83WsosvTZVF3UdDeHmVmwgytnRSkrhArIOa_Jly6tQEK2F.BQq.FZsJNCr.wzaQDG4qz5rvYZ3zODROHrMrLf3llzNxVCfjNm6zRVXN_olkP_373O6AOKOBMq9EN7RVE5_A1awAODWpj_TpiEenuMcr2cvI0._440cJeBdjDz.A9.4DWgN_C4xYqj6fhMOlfhzu93EPHZEsJWztrIg9uy5q6U4PBxYcdIxUSQjCXghirsIO7OM4li4nexBgVjkS1Iz6EaR4T1iWxBmNSPdiow1nJiFW9940dAzRClyumFxPH4Zu7pCIi6.JseK6K_349ahZXw7acBmfPav.cgM5rmFD7bDWpsYh7zdqnwxCWDuFPP52H05s9vHQbbVQMe_6y190jzmzVgBaIUNBXKVkQuxWuAhBIvmm085YWmscW4AGas1VSbcJ4w5PH3IpGulHuziMcCPBo7ED1KZOAhL8JwAVCEXAwhyfsz9v6jcf4tJMehgw.ul4Uw_KwnZawUBOfTSzLMPzWftJ0at8_Mbkv90OHgpefEuvd2wGN7cV8BHxsdtfCjZDGUAp5J1o9tX.VkUCvQ8dX17oTYv3WtiVlNs3msQXUohWBR2WoChrLueRiwmyvIztn1p2P3.NPZjDgLtnLMoTNDDrXLLQvpj.6A.lWd9AbsXhhumCuELfUM1Hoq2yu_Ccjzayxrn5uyx1UeGsMi7_lvuYiIUKDcXyN_UE0x7shMy8i3dHgSlnLjBSxEWSZUWR1JtNEKpWM0BXb3hnv3xifKTQaaWDFpPR9gEW78gMps9duJGGNO5VgkonccGPIsqgR3WwAkxNi5rebrSSHS4Ecb6ismkeLa8AyatijvJDFf.58.f7fadMnRvlcx.wCsBTDDfU1.RwFc_D_4S1OzZiGLNnxUxzaAGIvlCwTu0OcmPonEUgxauHO ...
# </p>
# </div>
# </div>
# <script>!function(){for(var s,o,d=(s=window.location.hostname,(o=s).endsWith("glassdoor.fr")?"fr-fr":o.endsWith("glassdoor.de")?"de-de":o.endsWith("glassdoor.nl")||o.endsWith("nl.glassdoor.be")?"nl-nl":o.endsWith("fr.glassdoor.be")||o.endsWith("fr.glassdoor.ch")?"fr-fr":o.endsWith("de.glassdoor.ch")||o.endsWith("glassdoor.at")?"de-de":o.endsWith("fr.glassdoor.ca")?"fr-fr":o.endsWith("glassdoor.es")?"es-es":o.endsWith("glassdoor.com.ar")||o.endsWith("glassdoor.com.mx")?"es-419":o.endsWith("glassdoor.com.br")?"pt-br":o.endsWith("glassdoor.it")?"it-it":"en-us"),e=document.getElementsByClassName("lang"),n=0,r=e.length;n<r;n++)-1==e[n].className.indexOf(d)&&(e[n].style.display="none")}();</script>
# <script>!function(e,a,t,n,g,c,o){e.GoogleAnalyticsObject=g,e.ga=e.ga||function(){(e.ga.q=e.ga.q||[]).push(arguments)},e.ga.l=1*new Date,c=a.createElement(t),o=a.getElementsByTagName(t)[0],c.async=1,c.src="//www.google-analytics.com/analytics.js",o.parentNode.insertBefore(c,o)}(window,document,"script",0,"ga"),ga("create","UA-2595786-6","auto"),ga("send","pageview");</script>
# </body>
# </html>

# %%
company=soup.find_all('div', class_='row d-flex flex-wrap')

# %%
soup.find_all('h')
# Out:
# []
