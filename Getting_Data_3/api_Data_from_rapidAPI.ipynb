# %%
import requests

url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Python developer in Texas, USA","page":"1","num_pages":"1"}

headers = {
	"X-RapidAPI-Key": "204722f6e3msh5734432a8137affp12180bjsncb64a292bdf0",
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': 'eb987405-d7bc-4bfb-bd79-d1b012836852', 'parameters': {'query': 'python developer in texas, usa', 'page': 1, 'num_pages': 1}, 'data': [{'job_id': 'Se73RDMZ0mXU9x1jAAAAAA==', 'employer_name': 'Reece USA', 'employer_logo': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQk3AoGfUp8KCgyugkW89_iK-oXwaCuTX5bH2Kd&s=0', 'employer_website': None, 'employer_company_type': None, 'job_publisher': 'LinkedIn', 'job_employment_type': 'FULLTIME', 'job_title': 'Python Developer', 'job_apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537', 'job_apply_is_direct': False, 'job_apply_quality_score': 0.6768, 'apply_options': [{'publisher': 'LinkedIn', 'apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537', 'is_direct': False}, {'publisher': 'Jobright AI', 'apply_link': 'https://jobright.ai/jobs/info/65e04a99575dfd5a802a4bd0', 'is_direct': False}], 'job_description': 'PLEASE NOTE THIS IS A PERMANE
# ...

# %%
response.json()
# Out:
# {'status': 'OK',
#  'request_id': 'eb987405-d7bc-4bfb-bd79-d1b012836852',
#  'parameters': {'query': 'python developer in texas, usa',
#   'page': 1,
#   'num_pages': 1},
#  'data': [{'job_id': 'Se73RDMZ0mXU9x1jAAAAAA==',
#    'employer_name': 'Reece USA',
#    'employer_logo': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQk3AoGfUp8KCgyugkW89_iK-oXwaCuTX5bH2Kd&s=0',
#    'employer_website': None,
#    'employer_company_type': None,
#    'job_publisher': 'LinkedIn',
#    'job_employment_type': 'FULLTIME',
#    'job_title': 'Python Developer',
#    'job_apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537',
#    'job_apply_is_direct': False,
#    'job_apply_quality_score': 0.6768,
#    'apply_options': [{'publisher': 'LinkedIn',
#      'apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537',
#      'is_direct': False},
#     {'publisher': 'Jobright AI',
# ...

# %%
response.json()['data']
# Out:
# [{'job_id': 'Se73RDMZ0mXU9x1jAAAAAA==',
#   'employer_name': 'Reece USA',
#   'employer_logo': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQk3AoGfUp8KCgyugkW89_iK-oXwaCuTX5bH2Kd&s=0',
#   'employer_website': None,
#   'employer_company_type': None,
#   'job_publisher': 'LinkedIn',
#   'job_employment_type': 'FULLTIME',
#   'job_title': 'Python Developer',
#   'job_apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537',
#   'job_apply_is_direct': False,
#   'job_apply_quality_score': 0.6768,
#   'apply_options': [{'publisher': 'LinkedIn',
#     'apply_link': 'https://www.linkedin.com/jobs/view/python-developer-at-reece-usa-3842330537',
#     'is_direct': False},
#    {'publisher': 'Jobright AI',
#     'apply_link': 'https://jobright.ai/jobs/info/65e04a99575dfd5a802a4bd0',
#     'is_direct': False}],
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame(response.json()['data'])

# %%
df.sample(2)
# Out:
#                      job_id                          employer_name  \
# 6  hdOxpkoK9sVp3gzXAAAAAA==                             SchooLinks
# 9  ARyA9QxnFe68fJcEAAAAAA==  United Software Group Inc. - US South
#
#                                        employer_logo  \
# 6  https://assets-global.website-files.com/60faf4...
# 9                                               None
#
#             employer_website employer_company_type job_publisher  \
# 6  http://www.schoolinks.com                  None         BeBee
# 9                       None                  None     Talentify
#
#   job_employment_type         job_title  \
# 6            FULLTIME  Python Developer
# 9            FULLTIME  Python Developer
#
#                                       job_apply_link  job_apply_is_direct  \
# 6  https://us.bebee.com/job/20240229-3e4b5e5df708...                False
# 9  https://www.talentify.io/job/python-developer-...                False
#
# ...

# %%
df.shape
# Out:
# (10, 41)

# %%
new_df=pd.DataFrame(response.json()['data'])[['employer_name', 'job_publisher', 'job_title','job_highlights',]]

# %%
new_df
# Out:
#                            employer_name job_publisher  \
# 0                              Reece USA      LinkedIn
# 1          Westinghouse Electric Company   Recruit.net
# 2                           Company Name  Radley James
# 3            Magnus Technology Solutions  ZipRecruiter
# 4                            SimplyApply      LinkedIn
# 5                          Goldman Sachs         BeBee
# 6                             SchooLinks         BeBee
# 7                                   Dice    Learn4Good
# 8                          SynergisticIT      LinkedIn
# 9  United Software Group Inc. - US South     Talentify
#
#                                            job_title  \
# 0                                   Python Developer
# 1                                   Python Developer
# 2            Python Developer – Houston, TX (Hybrid)
# 3                     Python Developer (Entry Level)
# 4          Senior Machine Learning Engineer (Python)
# ...

# %%
new_df['job_title'][0]
# Out:
# 'Python Developer'
